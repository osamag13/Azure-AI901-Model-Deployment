# %%
# %pip install openai
# %pip install python-dotenv

# %%
from openai import OpenAI

# %%
from openai import OpenAI

print("OpenAI package installed successfully!")

# %%
import openai
print(openai.__version__)

# %%
import os
from dotenv import load_dotenv
from openai import OpenAI

load_dotenv()

endpoint = "https://cmitctpfoundry.services.ai.azure.com/models/chat/completions?api-version=2024-05-01-preview"
api_key = os.getenv("AZURE_AI_KEY")

client = OpenAI(
    base_url=f"{endpoint}/openai/v1/",
    api_key=api_key
)

# %%
import os
from dotenv import load_dotenv
from openai import OpenAI

load_dotenv()

endpoint = "https://cmitctpfoundry.services.ai.azure.com/openai/v1/"
api_key = os.getenv("AZURE_AI_KEY")

client = OpenAI(
    base_url=endpoint,
    api_key=api_key
)

response = client.chat.completions.create(
    model="Phi-4-mini-reasoning",
    messages=[
        {
            "role": "user",
            "content": "What is the capital of France?"
        }
    ]
)

print(response.choices[0].message.content)
